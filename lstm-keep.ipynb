# %% [markdown]
# Like ocr-lstm-ctc-words but with ConvTranspose2d to get more output space.

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from importlib import reload
import os, sys, re, glob, time, pickle, IPython, logging
import scipy.ndimage as ndi
from itertools import islice
import torch
from torch import nn, optim
from torch.nn import functional as F
from torchmore import layers, flex
import torchtrainers as tt
from torch.utils.data import DataLoader
from webdataset import WebDataset
from ocrlib import ocrhelpers as helpers
from ocrlib.ocrhelpers import *
from ocrlib import ocrmodels as models
RUN("date"); RUN("hostname"); RUN("whoami"); RUN("nvidia-smi -L")

charset = "ABCDEFGHIJKLMNOPQRSTUVWXYZabcdefghijklmnopqrstuvwxyz"

def encode_str(s): 
    return [charset.find(c)+1 for c in s]

def decode_str(l): 
    return "".join([charset[k-1] for k in l])

transforms = [
    lambda x: (torch.tensor(x).float()/255.0).unsqueeze(0),
    lambda s: torch.tensor(encode_str(s)).long()
]
training = WebDataset("data/words-simple-training.tar", decoder="l8", 
                      extensions="jpg;jpeg;ppm;png txt", transforms=transforms)
testing = WebDataset("data/words-simple-test.tar", decoder="l8", 
                     extensions="jpg;jpeg;ppm;png txt", transforms=transforms)
training_dl = DataLoader(training, batch_size=5, collate_fn=helpers.collate4ocr)
testing_dl = DataLoader(testing, batch_size=20, collate_fn=helpers.collate4ocr)
next(iter(training_dl))[0].size()
# Out:
# date : Tue Oct  1 13:35:02 PDT 2019
# hostname : sedna
# whoami : tmb
# nvidia-smi -L : GPU 0: GeForce GTX 1080 Ti (UUID: GPU-2d5cf167-db75-89ec-c6f7-5639237768ce)
# torch.Size([5, 1, 112, 464])

# %%
# !awk '/lstm_keep/' RS="\n\n" ocrlib/ocrmodels.py
# Out:
# def make_lstm_keep(noutput=noutput):
#     model = nn.Sequential(
#         layers.Input("BDHW", range=(0, 1), sizes=[None, 1, None, None]),
#         layers.KeepSize(
#             mode="nearest",
#             dims=[3],
#             sub=nn.Sequential(
#                 *combos.conv2d_block(50, 3, repeat=2),
#                 *combos.conv2d_block(100, 3, repeat=2),
#                 *combos.conv2d_block(150, 3, repeat=2),
#                 layers.Fun("lambda x: x.sum(2)") # BDHW -> BDW
#             )
#         ),
#         flex.Conv1d(500, 5, padding=2),
#         flex.BatchNorm1d(),
#         nn.ReLU(),
#         layers.Reorder("BDL", "LBD"),
#         flex.LSTM(200, bidirectional=True),
#         layers.Reorder("LBD", "BDL"),
#         flex.Conv1d(noutput, 1),
#         layers.Reorder("BDL", "BLD")
#     )
#     flex.shape_inference(model, (1, 1, 128, 512))
#     return model

# %%
model = models.make("lstm_keep")
model
# Out:
# Sequential(
#   (0): Input(BDHW->BDHW torch.float32 (0, 1) cuda:0 [None, 1, None, None])
#   (1): KeepSize(
#     (sub): Sequential(
#       (0): Conv2d(1, 50, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): BatchNorm2d(50, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Conv2d(50, 50, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (4): BatchNorm2d(50, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU()
#       (6): Conv2d(50, 100, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (7): BatchNorm2d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (8): ReLU()
#       (9): Conv2d(100, 100, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (10): BatchNorm2d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (11): ReLU()
#       (12): Conv2d(100, 150, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (13): BatchNorm2d(150, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (14): ReLU()
#       (15): Conv2d(150, 150, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (16): BatchNorm2d(150, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (17): ReLU()
#       (18): Fun None lambda x: x.sum(2)
#     )
#   )
#   (2): Conv1d(150, 500, kernel_size=(5,), stride=(1,), padding=(2,))
#   (3): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (4): ReLU()
#   (5): Reorder("BDL", "LBD")
#   (6): LSTM(
#     (lstm): LSTM(500, 200, bidirectional=True)
#   )
#   (7): Reorder("LBD", "BDL")
#   (8): Conv1d(400, 53, kernel_size=(1,), stride=(1,))
#   (9): Reorder("BDL", "BLD")
# )

# %%
import torch.nn.functional as F
a = torch.rand(1, 17, 200, 300)
b = F.interpolate(a, size=[300, 400])
b.size()
# Out:
# torch.Size([1, 17, 300, 400])

# %%
trainer = helpers.LineTrainer(model, lr=1e-3)
trainer.train(training_dl, 10, every=60)
# Out:
# __MAXCOUNT__ 100

# %%
figsize(10, 10)
for i, batch in enumerate(islice(training_dl, 0, 10)):
    subplot(5, 2, i+1)
    result = trainer.predict_batch(batch[0], threshold=0.8)
    imshow(batch[0][0,0].detach().numpy())
    title(decode_str(result[0]))

# %%
trainer.errors(testing_dl)
# Out:
# (97, 101)
